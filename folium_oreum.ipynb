# %% [markdown]
# <a href="https://colab.research.google.com/github/jooooooing/plate_guide/blob/main/folium_oreum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.12.1.post1)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2022.9.24)

# %%
import numpy as np
import pandas as pd
import folium

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
# !pip3 install git+https://github.com/python-visualization/branca.git@master
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/python-visualization/branca.git@master
#   Cloning https://github.com/python-visualization/branca.git (to revision master) to /tmp/pip-req-build-9ot98mvd
#   Running command git clone -q https://github.com/python-visualization/branca.git /tmp/pip-req-build-9ot98mvd
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from branca==0.5.0+6.g35f4876) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->branca==0.5.0+6.g35f4876) (2.0.1)

# %%
m = folium.Map(
    location=[33.3621, 126.5291]
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f808e2a82b82ce244511397e570d624c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f808e2a82b82ce244511397e570d624c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f808e2a82b82ce244511397e570d624c = L.map(
#                 &quot;map_f808e2a82b82ce244511397e570d624c&quot;,
#                 {
#                     center: [33.3621, 126.5291],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91406e309c623fa8a6683e7bb21830b1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f808e2a82b82ce244511397e570d624c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %%
m = folium.Map(
    location=[33.3621, 126.5291],
    # tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!'

folium.Marker(
    [33.3621, 126.5291],
    popup = '<strong>hello world</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b2b716a02b0ec447cec39cbea09598e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b2b716a02b0ec447cec39cbea09598e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2b2b716a02b0ec447cec39cbea09598e = L.map(
#                 &quot;map_2b2b716a02b0ec447cec39cbea09598e&quot;,
#                 {
#                     center: [33.3621, 126.5291],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15603c23409f14c806a509d8f0bee14a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2b2b716a02b0ec447cec39cbea09598e);
#
#
#             var marker_2550e5bb6a7b49ee7a52d276d696d26a = L.marker(
#                 [33.3621, 126.5291],
#                 {}
#             ).addTo(map_2b2b716a02b0ec447cec39cbea09598e);
#
#
#         var popup_1a97e29f73389f5f5892e2932df95478 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_253a6edb1f801c37f0da5bca7dcce62a = $(`&lt;div id=&quot;html_253a6edb1f801c37f0da5bca7dcce62a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello world&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_1a97e29f73389f5f5892e2932df95478.setContent(html_253a6edb1f801c37f0da5bca7dcce62a);
#
#
#         marker_2550e5bb6a7b49ee7a52d276d696d26a.bindPopup(popup_1a97e29f73389f5f5892e2932df95478)
#         ;
#
#
#
#
#             marker_2550e5bb6a7b49ee7a52d276d696d26a.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[33.3621, 126.5291],
    # tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!'

folium.Marker(
    [33.3621, 126.5291],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.5106, 126.4913],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.4582, 126.9425],
    popup = '<strong>성산 일출봉</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b064f7256da443f4ef07af405c5db6cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b064f7256da443f4ef07af405c5db6cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b064f7256da443f4ef07af405c5db6cf = L.map(
#                 &quot;map_b064f7256da443f4ef07af405c5db6cf&quot;,
#                 {
#                     center: [33.3621, 126.5291],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4c0383423ad4009a65ddd9bb93b99fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b064f7256da443f4ef07af405c5db6cf);
#
#
#             var marker_9d0123ecd52ccdf26ad0d6de2c243dc6 = L.marker(
#                 [33.3621, 126.5291],
#                 {}
#             ).addTo(map_b064f7256da443f4ef07af405c5db6cf);
#
#
#         var popup_afeede21b875a20ea575f471ac7c36da = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_257b1f11345d5fe43e2226d3dc7a08fe = $(`&lt;div id=&quot;html_257b1f11345d5fe43e2226d3dc7a08fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_afeede21b875a20ea575f471ac7c36da.setContent(html_257b1f11345d5fe43e2226d3dc7a08fe);
#
#
#         marker_9d0123ecd52ccdf26ad0d6de2c243dc6.bindPopup(popup_afeede21b875a20ea575f471ac7c36da)
#         ;
#
#
#
#
#             marker_9d0123ecd52ccdf26ad0d6de2c243dc6.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_acc531f943fe7ded5c1171d2d66f3738 = L.marker(
#                 [33.5106, 126.4913],
#                 {}
#             ).addTo(map_b064f7256da443f4ef07af405c5db6cf);
#
#
#         var popup_2fdaac6afe3f71f92372e30343a97106 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4433207fb678f5e60269e5319f99c871 = $(`&lt;div id=&quot;html_4433207fb678f5e60269e5319f99c871&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_2fdaac6afe3f71f92372e30343a97106.setContent(html_4433207fb678f5e60269e5319f99c871);
#
#
#         marker_acc531f943fe7ded5c1171d2d66f3738.bindPopup(popup_2fdaac6afe3f71f92372e30343a97106)
#         ;
#
#
#
#
#             marker_acc531f943fe7ded5c1171d2d66f3738.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_02863a6983e4c0eb0e9ddb911d4b0f95 = L.marker(
#                 [33.4582, 126.9425],
#                 {}
#             ).addTo(map_b064f7256da443f4ef07af405c5db6cf);
#
#
#         var popup_3dbd182f0d991845a29db80aa46db2fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_4f83228b7488fe13044bff8a7b3155cb = $(`&lt;div id=&quot;html_4f83228b7488fe13044bff8a7b3155cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;성산 일출봉&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_3dbd182f0d991845a29db80aa46db2fb.setContent(html_4f83228b7488fe13044bff8a7b3155cb);
#
#
#         marker_02863a6983e4c0eb0e9ddb911d4b0f95.bindPopup(popup_3dbd182f0d991845a29db80aa46db2fb)
#         ;
#
#
#
#
#             marker_02863a6983e4c0eb0e9ddb911d4b0f95.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=[33.3621, 126.5291],
    # tiles = 'Stamen Terrain',
    zoom_start = 10
)

tooltip = 'Click!'

folium.Marker(
    [33.3621, 126.5291],
    popup = '<strong>한라산</strong>',
    tooltip = tooltip,
    icon = folium.Icon(color='#ff0000', icon = 'info-sign')
).add_to(m)

folium.Marker(
    [33.5106, 126.4913],
    popup = '<strong>제주국제공항</strong>',
    tooltip = tooltip
).add_to(m)

folium.Marker(
    [33.4582, 126.9425],
    popup = '<strong>성산 일출봉</strong>',
    tooltip = tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e5bac66008003b81f3f19779df6af2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e5bac66008003b81f3f19779df6af2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4e5bac66008003b81f3f19779df6af2d = L.map(
#                 &quot;map_4e5bac66008003b81f3f19779df6af2d&quot;,
#                 {
#                     center: [33.3621, 126.5291],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3745c974ca4670beeb91f3e6d7202b4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4e5bac66008003b81f3f19779df6af2d);
#
#
#             var marker_0fe774fc0ce0ec122246aa2ddeaf1db2 = L.marker(
#                 [33.3621, 126.5291],
#                 {}
#             ).addTo(map_4e5bac66008003b81f3f19779df6af2d);
#
#
#             var icon_4861d781cfcff8febfbbb666557987d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;#ff0000&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0fe774fc0ce0ec122246aa2ddeaf1db2.setIcon(icon_4861d781cfcff8febfbbb666557987d1);
#
#
#         var popup_40ca0d24a9b0c6e905987a940ca662e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_222e48963349bcbbdbb54b56f92fa229 = $(`&lt;div id=&quot;html_222e48963349bcbbdbb54b56f92fa229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;한라산&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_40ca0d24a9b0c6e905987a940ca662e1.setContent(html_222e48963349bcbbdbb54b56f92fa229);
#
#
#         marker_0fe774fc0ce0ec122246aa2ddeaf1db2.bindPopup(popup_40ca0d24a9b0c6e905987a940ca662e1)
#         ;
#
#
#
#
#             marker_0fe774fc0ce0ec122246aa2ddeaf1db2.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7de050708c752dc59be00491b463dfd9 = L.marker(
#                 [33.5106, 126.4913],
#                 {}
#             ).addTo(map_4e5bac66008003b81f3f19779df6af2d);
#
#
#         var popup_1c28195b8076be5d85a6e211b8437528 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ae9dc80201348e4b2d9f1844149aec46 = $(`&lt;div id=&quot;html_ae9dc80201348e4b2d9f1844149aec46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;제주국제공항&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_1c28195b8076be5d85a6e211b8437528.setContent(html_ae9dc80201348e4b2d9f1844149aec46);
#
#
#         marker_7de050708c752dc59be00491b463dfd9.bindPopup(popup_1c28195b8076be5d85a6e211b8437528)
#         ;
#
#
#
#
#             marker_7de050708c752dc59be00491b463dfd9.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bf88a62778acd4ec4df89f2d08155a51 = L.marker(
#                 [33.4582, 126.9425],
#                 {}
#             ).addTo(map_4e5bac66008003b81f3f19779df6af2d);
#
#
#         var popup_6af7d5164ab177222825a00d5c8886cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_380ee2e695fc044e666c073ce3cad4d5 = $(`&lt;div id=&quot;html_380ee2e695fc044e666c073ce3cad4d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;성산 일출봉&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_6af7d5164ab177222825a00d5c8886cd.setContent(html_380ee2e695fc044e666c073ce3cad4d5);
#
#
#         marker_bf88a62778acd4ec4df89f2d08155a51.bindPopup(popup_6af7d5164ab177222825a00d5c8886cd)
#         ;
#
#
#
#
#             marker_bf88a62778acd4ec4df89f2d08155a51.bindTooltip(
#                 `&lt;div&gt;
#                      Click!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
오름 = pd.read_csv('o.csv', encoding='cp949')
오름.tail()
# Out:
#     읍면동    오름명                      소재지         위도          경도 주차장 화장실  표고(m)  \
# 63  서홍동    시오름     제주특별자치도 서귀포시 서홍동 산 1  33.361667  126.529167   N   N  757.8
# 64  대륜동    고근산  제주특별자치도 서귀포시 서호동 1286-1  33.266364  126.512309   Y   Y  396.2
# 65  중문동   거린사슴   제주특별자치도 서귀포시 대포동 산 2-1  33.307313  126.454127   Y   Y  742.9
# 66  중문동  베릿내오름    제주특별자치도 서귀포시 중문동 3712  33.251430  126.434824   Y   Y  101.2
# 67  중문동    법정악     제주특별자치도 서귀포시 하원동 산 1  33.258346  126.452100   Y   Y  760.1
#
#        데이터기준일자
# 63  2022-05-10
# 64  2022-05-10
# 65  2022-05-10
# 66  2022-05-10
# 67  2022-05-10

# %%
오름.isnull().sum()
# Out:
# 읍면동        0
# 오름명        0
# 소재지        0
# 위도         0
# 경도         0
# 주차장        0
# 화장실        0
# 표고(m)      0
# 데이터기준일자    0
# dtype: int64

# %%
오름[['화장실']].value_counts()
# Out:
# 화장실
# N      41
# Y      27
# dtype: int64

# %%
오름.iloc[0]['오름명']
오름.iloc[0]['위도']
오름.iloc[0]['경도']
# Out:
# 126.2907797

# %%
오름.shape
# Out:
# (68, 9)

# %%
for i in range(오름.shape[0]):
  print(오름.iloc[i]['오름명'], 오름.iloc[0]['위도'], 오름.iloc[0]['경도'])
# Out:
# 송악산(절울이) 33.1994088 126.2907797
# 섯알오름 33.1994088 126.2907797
# 가시오름  33.1994088 126.2907797
# 녹남봉 33.1994088 126.2907797
# 물영아리 33.1994088 126.2907797
# 머체오름 33.1994088 126.2907797
# 이승이 33.1994088 126.2907797
# 사려니오름 33.1994088 126.2907797
# 민오름 33.1994088 126.2907797
# 운지오름 33.1994088 126.2907797
# 자배봉 33.1994088 126.2907797
# 생길이 33.1994088 126.2907797
# 큰걸세 33.1994088 126.2907797
# 족은걸세 33.1994088 126.2907797
# 수악 33.1994088 126.2907797
# 한남리머체왓숲길 33.1994088 126.2907797
# 일출봉 33.1994088 126.2907797
# 멀미오름 33.1994088 126.2907797
# 멀미알오름 33.1994088 126.2907797
# 식산봉(바우오름) 33.1994088 126.2907797
# 큰물메(대왕수봉) 33.1994088 126.2907797
# 궁대악 33.1994088 126.2907797
# 뒤꾸부니 33.1994088 126.2907797
# 모구리오름 33.1994088 126.2907797
# 유건에오름 33.1994088 126.2907797
# 통오름 33.1994088 126.2907797
# 독자봉 33.1994088 126.2907797
# 남산봉 33.1994088 126.2907797
# 낭끼오름 33.1994088 126.2907797
# 모구리알오름 33.1994088 126.2907797
# 대왕산 33.1994088 126.2907797
# 군산 33.1994088 126.2907797
# 단산(바굼지오름) 33.1994088 126.2907797
# 월라봉(다래오름) 33.1994088 126.2907797
# 대병악(여진머리) 33.1994088 126.2907797
# 북오름 33.1994088 126.2907797
# 남송악(남소로기) 33.1994088 126.2907797
# 광해악(넙게오름) 33.1994088 126.2907797
# 논오름 33.1994088 126.2907797
# 금산 33.1994088 126.2907797
# 용머리 33.1994088 126.2907797
# 왕이메 33.1994088 126.2907797
# 따라비오름 33.1994088 126.2907797
# 대록산(큰사슴이) 33.1994088 126.2907797
# 달산봉 33.1994088 126.2907797
# 제석오름 33.1994088 126.2907797
# 매봉 33.1994088 126.2907797
# 영주산 33.1994088 126.2907797
# 좌보미 33.1994088 126.2907797
# 백약이오름 33.1994088 126.2907797
# 갑선이 33.1994088 126.2907797
# 가세오름 33.1994088 126.2907797
# 토산봉 33.1994088 126.2907797
# 붉은오름 33.1994088 126.2907797
# 개오름 33.1994088 126.2907797
# 갑마장길 33.1994088 126.2907797
# 제지오름(절오름) 33.1994088 126.2907797
# 월라산(도라미) 33.1994088 126.2907797
# 칡오름 33.1994088 126.2907797
# 영천오름 33.1994088 126.2907797
# 미악산(솔오름) 33.1994088 126.2907797
# 삼매봉 33.1994088 126.2907797
# 하논-보로미 33.1994088 126.2907797
# 시오름 33.1994088 126.2907797
# 고근산 33.1994088 126.2907797
# 거린사슴 33.1994088 126.2907797
# 베릿내오름 33.1994088 126.2907797
# 법정악 33.1994088 126.2907797

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<strong>{오름.iloc[i]["오름명"]}</strong>',
        tooltip = tooltip
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61b113c3947dd74ad2cb0b340207796e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61b113c3947dd74ad2cb0b340207796e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_61b113c3947dd74ad2cb0b340207796e = L.map(
#                 &quot;map_61b113c3947dd74ad2cb0b340207796e&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5ba2bf52419e34cebbcb3989c80194c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_61b113c3947dd74ad2cb0b340207796e);
#
#
#             var marker_51c2e13c205f3e7c3fe610c5a015cb1d = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_61b113c3947dd74ad2cb0b340207796e);
#
#
#         var popup_e4976617c0280c0ee9b519a27d4a88d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ba7a6a55f7a9b823b6e22650f6e23332 = $(`&lt;div id=&quot;html_ba7a6a55f7a9b823b6e22650f6e23332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_e4976617c0280c0ee9b519a27d4a88d5.setContent(html_ba7a6a55f7a9b823b6e22650f6e23332);
#
#
#         marker_51c2e13c205f3e7c3fe610c5a015cb1d.bindPopup(popup_e4976617c0280c0ee9b519a27d4a88d5)
#         ;
#
#
#
#
#             marker_51c2e13c205f3e7c3fe610c5a015cb1d.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bc561ff53bf3cc6f6bd9c5866f18eaa2 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_61b113c3947dd74ad2cb0b340207796e);
#
#
#         var popup_8d39d7d062b932fe6848295d281b191b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_cbad1c08dbbe3b171a492a61d2dac7f1 = $(`&lt;div id=&quot;html_cbad1c08dbbe3b171a492a61d2dac7f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_8d39d7d062b932fe6848295d281b191b.setContent(html_cbad1c08dbbe3b171a492a61d2dac7f1);
#
#
#         marker_bc561ff53bf3cc6f6bd9c5866f18eaa2.bindPopup(popup_8d39d7d062b932fe6848295d281b191b)
#         ;
#
#
#
#
#             marker_bc561ff53bf3cc6f6bd9c5866f18eaa2.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_16701f6c68f21d785cc6979f9d4ce32a = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_61b113c3947dd74ad2cb0b340207796e);
#
#
#         var popup_b942b01454c3fbfbc55cf68daf786a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_507a403b7668f5446802a4b212e25bbf = $(`&lt;div id=&quot;html_507a403b7668f5446802a4b212e25bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_b942b01454c3fbfbc55cf68daf786a76.setContent(html_507a403b7668f5446802a4b212e25bbf);
#
#
#         marker_16701f6c68f21d785cc6979f9d4ce32a.bindPopup(popup_b942b01454c3fbfbc55cf68daf786a76)
#         ;
#
#
#
#
#             marker_16701f6c68f21d785cc6979f9d4ce32a.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fd761fdea3265e3d05747932591788aa = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_61b113c3947dd74ad2cb0b340207796e);
#
#
#         var popup_f6d61ed813964e0e1fcd127aecaf3d64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b3b4bc7588ce7647fd188fcce2a70a35 = $(`&lt;div id=&quot;html_b3b4bc7588ce7647fd188fcce2a70a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;/div&gt;`)[0];
#             popup_f6d61ed813964e0e1fcd127aecaf3d64.setContent(html_b3b4bc7588ce7647fd188fcce2a70a35);
#
#
#         marker_fd761fdea3265e3d05747932591788aa.bindPopup(popup_f6d61ed813964e0e1fcd127aecaf3d64)
#         ;
#
#
#
#
#             marker_fd761fdea3265e3d05747932591788aa.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b04586d3ccd1d908a1c797df5e8f79fa = L.marker(
#                 [33.3708091, 126.6935196],
#                 {}
#             ).addTo(map_61b113c3947dd74ad

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실 : {오름.iloc[i]["화장실"]}<br>\</div>',
        tooltip = tooltip
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_870e6dacf23f9acc1814836abdd0d985 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_870e6dacf23f9acc1814836abdd0d985&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_870e6dacf23f9acc1814836abdd0d985 = L.map(
#                 &quot;map_870e6dacf23f9acc1814836abdd0d985&quot;,
#                 {
#                     center: [33.3684955195788, 126.52918183373025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae4854916f216d72ed5e6b494c074e6d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_870e6dacf23f9acc1814836abdd0d985);
#
#
#             var marker_6eec928587e53b0de00eb96d0b650a71 = L.marker(
#                 [33.1994088, 126.2907797],
#                 {}
#             ).addTo(map_870e6dacf23f9acc1814836abdd0d985);
#
#
#         var popup_731c14242ebc5e6b02e3474a6db8cfa9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d29b783e49c31f97b638b30cafd4e2bf = $(`&lt;div id=&quot;html_d29b783e49c31f97b638b30cafd4e2bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;송악산(절울이)&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;\&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_731c14242ebc5e6b02e3474a6db8cfa9.setContent(html_d29b783e49c31f97b638b30cafd4e2bf);
#
#
#         marker_6eec928587e53b0de00eb96d0b650a71.bindPopup(popup_731c14242ebc5e6b02e3474a6db8cfa9)
#         ;
#
#
#
#
#             marker_6eec928587e53b0de00eb96d0b650a71.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3e5f632f768ee7f4d59fe58fc83a3006 = L.marker(
#                 [33.2042537, 126.281676],
#                 {}
#             ).addTo(map_870e6dacf23f9acc1814836abdd0d985);
#
#
#         var popup_3bbafe2d862ba4c9902610bae8b57ca1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f39205c9509e5cb0437a44d73c2dec48 = $(`&lt;div id=&quot;html_f39205c9509e5cb0437a44d73c2dec48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;섯알오름&lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : Y&lt;br&gt;\&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_3bbafe2d862ba4c9902610bae8b57ca1.setContent(html_f39205c9509e5cb0437a44d73c2dec48);
#
#
#         marker_3e5f632f768ee7f4d59fe58fc83a3006.bindPopup(popup_3bbafe2d862ba4c9902610bae8b57ca1)
#         ;
#
#
#
#
#             marker_3e5f632f768ee7f4d59fe58fc83a3006.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_014bad9f0e6341680f13fee98d75b352 = L.marker(
#                 [33.2533626, 126.2490546],
#                 {}
#             ).addTo(map_870e6dacf23f9acc1814836abdd0d985);
#
#
#         var popup_5a96481610fbc620298b3a9d8c7b80ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_47f71f0acbf0e0027d3bdcfeec425bbd = $(`&lt;div id=&quot;html_47f71f0acbf0e0027d3bdcfeec425bbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;가시오름 &lt;/strong&gt;&lt;br&gt;        주차장 : Y&lt;br&gt;        화장실 : N&lt;br&gt;\&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_5a96481610fbc620298b3a9d8c7b80ba.setContent(html_47f71f0acbf0e0027d3bdcfeec425bbd);
#
#
#         marker_014bad9f0e6341680f13fee98d75b352.bindPopup(popup_5a96481610fbc620298b3a9d8c7b80ba)
#         ;
#
#
#
#
#             marker_014bad9f0e6341680f13fee98d75b352.bindTooltip(
#                 `&lt;div&gt;
#                      Click!!
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e483aa85f0ff4a72a2382b33b823f216 = L.marker(
#                 [33.2798153, 126.1954827],
#                 {}
#             ).addTo(map_870e6dacf23f9acc1814836abdd0d985);
#
#
#         var popup_d960628d4665fd0e8306c226d66fe8c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_268b6c5a7e06d253bd139e8745fbfc86 = $(`&lt;div id=&quot;html_268b6c5a7e06d253bd139e8745fbfc86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&quot;width:100px&quot;&gt;&lt;strong&gt;녹남봉&lt;/strong&gt;&lt;br&gt;        주차장 : N&lt;br&gt;        화장실 : N&lt;br&gt;\&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_d960628d4665fd0e8306c226d66fe8c1.setContent(html_268b6c5a7e06d253bd139e8745fbfc86);
#
#
#         marker_e483aa85f0ff4a72a2382b33b823f216.bindPopup(popup_d96062

# %%
m = folium.Map(
    location = [33.3684955195788, 126.52918183373025],
    zoom_start = 10
)

tooltip = 'Click!!'

for i in range(오름.shape[0]):
    folium.Marker(
        [오름.iloc[i]['위도'], 오름.iloc[i]['경도']],
        popup = f'<div style="width:100px"><strong>{오름.iloc[i]["오름명"]}</strong><br>\
        주차장 : {오름.iloc[i]["주차장"]}<br>\
        화장실 : {오름.iloc[i]["화장실"]}<br>\
        <img width="80px" src="a.jpg"><br>\
        <a href="https://www.kopo.ac.kr/ctc/index.do">상세페이지 이동</a></div>',
        tooltip = tooltip
    ).add_to(m)

m.save('index.html')
